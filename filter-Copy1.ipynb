# %% [markdown]
# ## GWAS catalog filtering notebook

# %% [markdown]
# The purpose of this notebook is to filter GWAS associations and traits based on the curation comments and our needs

# %%
import polars as pl
from pathlib import *

# %% [markdown]
# ### Setting up paths

# %%
base = Path(".")
data = base / "data"
input = data / "input"
output = data / "output"

# %%
traits_path = input / "traits_no_measurement.tsv"
traits_df = pl.read_csv(str(traits_path), sep="\t")
traits_df.head(3)
# Out:
# shape: (3, 6)
# ┌────────────────────┬─────────────────────────────────────┬─────────┬────────────────────┬────────┬─────────────────┐
# │ trait              ┆ trait_uri                           ┆ studies ┆ association_counts ┆ papers ┆ Olga's comments │
# │ ---                ┆ ---                                 ┆ ---     ┆ ---                ┆ ---    ┆ ---             │
# │ str                ┆ str                                 ┆ i64     ┆ i64                ┆ i64    ┆ str             │
# ╞════════════════════╪═════════════════════════════════════╪═════════╪════════════════════╪════════╪═════════════════╡
# │ clinical treatment ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 687     ┆ 31                 ┆ 687    ┆ null            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ employment status  ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 687     ┆ 10                 ┆ 687    ┆ null            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ cortical thickness ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 325     ┆ 1292               ┆ 325    ┆ null            │
# └────────────────────┴─────────────────────────────────────┴─────────┴────────────────────┴────────┴─────────────────┘

# %% [markdown]
# Filter by curators comments and fix typos

# %%
comments = traits_df["Olga's comments"].to_list()

curator_comments = (
    pl.col("Olga's comments")
        .str.strip() # steam leading and ending spaces, they are often added accidentally and cause troubles
        .str.to_lowercase()
        .str.replace(" ", "_") # let's go dash instead of spaces
        .str.replace("/", ", ").str.replace("\?",  "") #clean up from some redundant symbols
        .str.replace("muskuloskeletal", "musculoskeletal").str.replace('musculosceletal', "musculoskeletal") # typos correction
        .str.replace("obesiy", 'obesity')
        .str.replace("homeostais","homeostasis")
        .str.replace(", ", "_and_").str.replace(",", "_and_") #let's first use end and then check if we can go further
) # cleaned up Olga's comments column

traits_filtered: pl.DataFrame = traits_df.filter(pl.col("Olga's comments").is_not_null())\
    .with_column(curator_comments).rename({"Olga's comments": "curator_comments"})
traits_filtered.head(10)
# Out:
# shape: (10, 6)
# ┌──────────────────────────┬─────────────────────────────────────┬─────────┬────────────────────┬────────┬─────────────────────────────────┐
# │ trait                    ┆ trait_uri                           ┆ studies ┆ association_counts ┆ papers ┆ curator_comments                │
# │ ---                      ┆ ---                                 ┆ ---     ┆ ---                ┆ ---    ┆ ---                             │
# │ str                      ┆ str                                 ┆ i64     ┆ i64                ┆ i64    ┆ str                             │
# ╞══════════════════════════╪═════════════════════════════════════╪═════════╪════════════════════╪════════╪═════════════════════════════════╡
# │ type 2 diabetes mellitus ┆ http://purl.obolibrary.org/obo/M... ┆ 175     ┆ 5003               ┆ 175    ┆ glucose_homeostasis_and_obesity │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ body mass index          ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 151     ┆ 8912               ┆ 151    ┆ glucose_homeostasis_and_obesity │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ COVID-19                 ┆ http://purl.obolibrary.org/obo/M... ┆ 123     ┆ 659                ┆ 123    ┆ lung                            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ asthma                   ┆ http://purl.obolibrary.org/obo/M... ┆ 112     ┆ 1475               ┆ 112    ┆ lung                            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...                      ┆ ...                                 ┆ ...     ┆ ...                ┆ ...    ┆ ...                             │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ systolic blood pressure  ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 73      ┆ 3435               ┆ 73     ┆ cardiovascular                  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ coronary artery disease  ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 72      ┆ 2408               ┆ 72     ┆ cardiovascular                  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ diastolic blood pressure ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 68      ┆ 2316               ┆ 68     ┆ cardiovascular                  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ osteoarthritis           ┆ http://purl.obolibrary.org/obo/M... ┆ 60      ┆ 99                 ┆ 60     ┆ musculoskeletal                 │
# └──────────────────────────┴─────────────────────────────────────┴─────────┴────────────────────┴────────┴─────────────────────────────────┘

# %%
traits_grouped = traits_filtered.groupby("curator_comments").agg(pl.all())

traits = traits_grouped.explode([c for c in traits_grouped.columns if c != "curator_comments"])
traits.head(10)
# Out:
# shape: (10, 6)
# ┌─────────────────────────────────┬─────────────────────────────────────┬─────────────────────────────────────┬─────────┬────────────────────┬────────┐
# │ curator_comments                ┆ trait                               ┆ trait_uri                           ┆ studies ┆ association_counts ┆ papers │
# │ ---                             ┆ ---                                 ┆ ---                                 ┆ ---     ┆ ---                ┆ ---    │
# │ str                             ┆ str                                 ┆ str                                 ┆ i64     ┆ i64                ┆ i64    │
# ╞═════════════════════════════════╪═════════════════════════════════════╪═════════════════════════════════════╪═════════╪════════════════════╪════════╡
# │ glucose_homeostasis_and_obesity ┆ type 2 diabetes mellitus            ┆ http://purl.obolibrary.org/obo/M... ┆ 175     ┆ 5003               ┆ 175    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ glucose_homeostasis_and_obesity ┆ body mass index                     ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 151     ┆ 8912               ┆ 151    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ glucose_homeostasis_and_obesity ┆ fat body mass                       ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 40      ┆ 184                ┆ 40     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ glucose_homeostasis_and_obesity ┆ obesity                             ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 38      ┆ 196                ┆ 38     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ ...                             ┆ ...                                 ┆ ...                                 ┆ ...     ┆ ...                ┆ ...    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ glucose_homeostasis_and_obesity ┆ body fat percentage                 ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 23      ┆ 527                ┆ 23     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ glucose_homeostasis_and_obesity ┆ metabolic syndrome                  ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 22      ┆ 233                ┆ 22     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ glucose_homeostasis_and_obesity ┆ non-alcoholic fatty liver diseas... ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 22      ┆ 169                ┆ 22     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ glucose_homeostasis_and_obesity ┆ insulin resistance                  ┆ http://www.ebi.ac.uk/efo/EFO_000... ┆ 12      ┆ 21                 ┆ 12     │
# └─────────────────────────────────┴─────────────────────────────────────┴─────────────────────────────────────┴─────────┴────────────────────┴────────┘

# %% [markdown]
# ## Writing results to folders

# %% [markdown]
# let's clean the output first

# %%
import shutil
if output.exists():
    shutil.rmtree(output)
output.mkdir()

# %% [markdown]
# Let's create folders for modules

# %%
modules = traits_filtered.select([pl.col("curator_comments").unique()]).to_series().to_list()
modules
# Out:
# ['musculoskeletal',
#  'cardiovascular',
#  'inflammation',
#  'mental',
#  'metabolic_health_and_obesity',
#  'glucose_homeostasis_and_obesity',
#  'other',
#  'lung',
#  'longevity']

# %%
df_list = []

for item in modules:           
    item_folder = output / item
    item_folder.mkdir()
    file_name = item + '.tsv'
    file_path = item_folder / file_name
    print(f"writing module {item} to {item_folder} with traits file {file_path}\n")
    module_df = traits.filter(pl.col('curator_comments')==item)

    module_df.write_csv(file = str(file_path), sep='\t')
# Out:
# writing module musculoskeletal to data\output\musculoskeletal with traits file data\output\musculoskeletal\musculoskeletal.tsv
#
# writing module cardiovascular to data\output\cardiovascular with traits file data\output\cardiovascular\cardiovascular.tsv
#
# writing module inflammation to data\output\inflammation with traits file data\output\inflammation\inflammation.tsv
#
# writing module mental to data\output\mental with traits file data\output\mental\mental.tsv
#
# writing module metabolic_health_and_obesity to data\output\metabolic_health_and_obesity with traits file data\output\metabolic_health_and_obesity\metabolic_health_and_obesity.tsv
#
# writing module glucose_homeostasis_and_obesity to data\output\glucose_homeostasis_and_obesity with traits file data\output\glucose_homeostasis_and_obesity\glucose_homeostasis_and_obesity.tsv
#
# writing module other to data\output\other with traits file data\output\other\other.tsv
#
# writing module lung to data\output\lung with traits file data\output\lung\lung.tsv
#
# writing module longevity to data\output\longevity with traits file data\output\longevity\longevity.tsv

# %% [markdown]
# dowloading GWASS catalogs to input folder

# %%
import urllib.request

# Associations file v1.0.2

associations_link = "https://www.ebi.ac.uk/gwas/api/search/downloads/alternative"
local_associations = "gwass_associations.tsv" 
path_associations = input / local_associations

urllib.request.urlretrieve(associations_link, path_associations)


# Studies file v1.0.3

studies_link = "https://www.ebi.ac.uk/gwas/api/search/downloads/studies_new"
local_studies = "gwass_studies.tsv"
path_studies = input / local_studies

urllib.request.urlretrieve(studies_link, path_studies)

# %%
# for local work if catalogas already downloaded

local_associations = "gwass_associations.tsv" 
path_associations = input / local_associations

local_studies = "gwass_studies.tsv"
path_studies = input / local_studies

# %% [markdown]
# reading gwass catalogues and filtering needed rows

# %%
associations_df = pl.read_csv(str(path_associations),{'CHR_ID': utf}, sep="\t") 
associations_df.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17840\2283892044.py in <module>
# ----> 1 associations_df = pl.read_csv(str(path_associations),{'CHR_ID': str}, sep="\t")
#       2 associations_df.head(3)
#
# ~\.conda\envs\py39\lib\site-packages\polars\utils.py in wrapper(*args, **kwargs)
#     308         def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     309             _rename_kwargs(fn.__name__, kwargs, aliases)
# --> 310             return fn(*args, **kwargs)
#     311
#     312         return wrapper
#
# ~\.conda\envs\py39\lib\site-packages\polars\io.py in read_csv(file, has_header, columns, new_columns, sep, comment_char, quote_char, skip_rows, dtypes, null_values, ignore_errors, parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_count_name, row_count_offset, sample_size, eol_char)
#     385         file, encoding=encoding, use_pyarrow=False, **storage_options
#     386     ) as data:
# --> 387         df = DataFrame._read_csv(
#     388             file=data,
#     389             has_header=has_header,
#
# ~\.conda\envs\py39\lib\site-packages\polars\internals\dataframe\frame.py in _read_csv(cls, file, has_header, columns, sep, comment_char, quote_char, skip_rows, dtypes, null_values, ignore_errors, parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_count_name, row_count_offset, sample_size, eol_char)
#     597         projection, columns = handle_projection_columns(columns)
#     598
# --> 599         self._df = PyDataFrame.read_csv(
#     600             file,
#     601             infer_schema_length,
#
# TypeError: argument 'has_header': 'dict' object cannot be converted to 'PyBool'

# %%
studies_df = pl.read_csv(str(path_studies), sep="\t")
studies_df.head(3)
# Out:
# shape: (3, 22)
# ┌───────────────────────┬───────────┬──────────────┬────────────┬─────┬───────────────────┬──────────────────┬─────────────────────────┬─────────────────────────────┐
# │ DATE ADDED TO CATALOG ┆ PUBMED ID ┆ FIRST AUTHOR ┆ DATE       ┆ ... ┆ STATISTICAL MODEL ┆ BACKGROUND TRAIT ┆ MAPPED BACKGROUND TRAIT ┆ MAPPED BACKGROUND TRAIT URI │
# │ ---                   ┆ ---       ┆ ---          ┆ ---        ┆     ┆ ---               ┆ ---              ┆ ---                     ┆ ---                         │
# │ str                   ┆ i64       ┆ str          ┆ str        ┆     ┆ str               ┆ str              ┆ str                     ┆ str                         │
# ╞═══════════════════════╪═══════════╪══════════════╪════════════╪═════╪═══════════════════╪══════════════════╪═════════════════════════╪═════════════════════════════╡
# │ 2016-10-14            ┆ 26626624  ┆ Stuart PE    ┆ 2015-11-28 ┆ ... ┆ null              ┆ null             ┆ null                    ┆ null                        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-10-14            ┆ 26626624  ┆ Stuart PE    ┆ 2015-11-28 ┆ ... ┆ null              ┆ null             ┆ null                    ┆ null                        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-10-14            ┆ 26626624  ┆ Stuart PE    ┆ 2015-11-28 ┆ ... ┆ null              ┆ null             ┆ null                    ┆ null                        │
# └───────────────────────┴───────────┴──────────────┴────────────┴─────┴───────────────────┴──────────────────┴─────────────────────────┴─────────────────────────────┘

# %% [markdown]
# filtering studies

# %%
folders = output.iterdir()
folders
# Out:
# <generator object Path.iterdir at 0x000001EA9AF4D430>

# %%
for f in folders:
    file_name = f.iterdir()
    df_path = f / file_name
    df = pl.read_csv(df_path, sep="\t")
    df.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17840\2065446752.py in <module>
#       1 for f in folders:
#       2     file_name = f.iterdir()
# ----> 3     df_path = f / file_name
#       4     df = pl.read_csv(df_path, sep="\t")
#       5     df.head(3)
#
# TypeError: unsupported operand type(s) for /: 'WindowsPath' and 'generator'
